# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/victorwong/opt/miniconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("player_premier_league_defensive (1).csv")

# %%
man = df[df["Squad"]=="Manchester City"]
tot = df[df["Squad"]=="Tottenham"]
conc = pd.concat([man, tot])
conc
# Out:
#      Unnamed: 0             Player   Nation    Pos            Squad  Age  \
# 9             9      Manuel Akanji   ch SUI     DF  Manchester City   27
# 10           10         Nathan Aké   nl NED     DF  Manchester City   27
# 18           18     Julián Álvarez   ar ARG  FW,MF  Manchester City   22
# 80           80       João Cancelo   pt POR     DF  Manchester City   28
# 93           93       Shea Charles  nir NIR     DF  Manchester City   18
# 127         127    Kevin De Bruyne   be BEL     MF  Manchester City   31
# 135         135         Rúben Dias   pt POR     DF  Manchester City   25
# 154         154            Ederson   br BRA     GK  Manchester City   28
# 176         176         Phil Foden  eng ENG     FW  Manchester City   22
# 204         204       Sergio Gómez   es ESP  DF,MF  Manchester City   21
# 208         208      Jack Grealish  eng ENG     FW  Manchester City   26
# 215         215     İlkay Gündoğan   de GER     MF  Manchester City   31
# ...

# %%
conc.plot.bar(x='Squad', y=['Total_Tackle', 'Tackle_Won', 'Mid3rd_Tackle'],figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Squad'>

# %%
df["Player"]
# Out:
# 0         Brenden Aaronson
# 1            George Abbott
# 2                Che Adams
# 3              Tyler Adams
# 4         Tosin Adarabioyo
#               ...
# 564          Jordan Zemura
# 565    Oleksandr Zinchenko
# 566           Hakim Ziyech
# 567             Kurt Zouma
# 568        Martin Ødegaard
# Name: Player, Length: 569, dtype: object

# %%
df
# Out:
#      Unnamed: 0               Player   Nation    Pos         Squad  Age  \
# 0             0     Brenden Aaronson   us USA  MF,FW  Leeds United   21
# 1             1        George Abbott  eng ENG     MF     Tottenham   16
# 2             2            Che Adams  sct SCO     FW   Southampton   26
# 3             3          Tyler Adams   us USA     MF  Leeds United   23
# 4             4     Tosin Adarabioyo  eng ENG     DF        Fulham   24
# ..          ...                  ...      ...    ...           ...  ...
# 564         564        Jordan Zemura   zw ZIM     DF   Bournemouth   22
# 565         565  Oleksandr Zinchenko   ua UKR     DF       Arsenal   25
# 566         566         Hakim Ziyech   ma MAR  FW,MF       Chelsea   29
# 567         567           Kurt Zouma   fr FRA     DF      West Ham   27
# 568         568      Martin Ødegaard   no NOR     MF       Arsenal   23
#
#      90s_played  Total_Tackle  Tackle_Won  Def3rd_Tackle  ...  Att3rd_Tackle  \
# ...

# %%
df["Unnamed: 0"]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 564    564
# 565    565
# 566    566
# 567    567
# 568    568
# Name: Unnamed: 0, Length: 569, dtype: int64

# %%
df.drop(columns= ['Unnamed: 0','Player', 'Nation',"Pos"], axis=1, inplace=True)

# %%
df
# Out:
#             Squad  Age  90s_played  Total_Tackle  Tackle_Won  Def3rd_Tackle  \
# 0    Leeds United   21        26.4            45          18             16
# 1       Tottenham   16         0.0             0           0              0
# 2     Southampton   26        22.1            17          13              7
# 3    Leeds United   23        24.0            89          46             44
# 4          Fulham   24        23.2            30          13             22
# ..            ...  ...         ...           ...         ...            ...
# 564   Bournemouth   22        16.2            39          24             24
# 565       Arsenal   25        23.5            40          18             14
# 566       Chelsea   29         7.3            20          12             12
# 567      West Ham   27        22.1             9           4              4
# 568       Arsenal   23        34.7            36          23             12
#
# ...

# %%
df_dropped

# %%
average = df.groupby('Squad').mean()
average
# Out:
#                        Age  90s_played  Total_Tackle  Tackle_Won  \
# Squad
# Arsenal          23.961538   16.069231     21.846154   13.192308
# Aston Villa      26.576923   16.061538     24.346154   13.000000
# Bournemouth      25.258065   13.483871     19.935484   11.967742
# Brentford        25.000000   16.716000     23.480000   13.480000
# Brighton         23.482759   14.424138     21.241379   11.724138
# Chelsea          24.656250   13.031250     23.125000   13.906250
# Crystal Palace   25.653846   16.030769     26.538462   16.192308
# Everton          25.428571   14.903571     25.285714   15.142857
# Fulham           26.482759   14.379310     21.551724   12.068966
# Leeds United     24.241379   14.393103     28.965517   16.551724
# Leicester City   25.607143   14.917857     25.000000   14.714286
# Liverpool        25.357143   14.914286     21.071429   13.214286
# Manchester City  25.458333   17.383333     19.625000   11.333333
# ...

# %%
ax = average.T.plot(kind="bar",figsize=(20,10))



ax.set_xlabel("Columns", fontsize=14)  
ax.set_ylabel("Mean", fontsize=14)  

plt.tight_layout()
plt.show()

# %%
df_numbers = df.drop('Player', axis=1, inplace=True)
df_numbers

# %%
print(df_numbers)
# Out:
# None
